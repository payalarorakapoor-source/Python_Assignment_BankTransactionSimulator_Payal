# %%
# Python String Methods with Output

# %%
#Demo of upper()
s='Learning of Python'
print(s.upper())
# Out:
# LEARNING OF PYTHON

# %%
#Demo of isLower()
"HELLO HOW ARE YOU ALL".islower()
# Out:
# False

# %%
#Demo of Lower()
s='PYTHON IS A LANGUAGE'
print(s.lower())
# Out:
# python is a language

# %%
#Demo of isupper()
s='PYTHON IS A LANGUAGE'
print(s.isupper())
# Out:
# True

# %%
# Demo of zfill()
num = "50"

x = num.zfill(20)

print(x)

txt = "hello world"

x = txt.zfill(30)

print(x)
# Out:
# 00000000000000000050
# 0000000000000000000hello world

# %%
# Demo of capitalize()
str = "hello all welcome to my world."

x = str.capitalize()

print (x)
# Out:
# Hello all welcome to my world.

# %%
# Demo of casefold()
str = "HELLO ALL WELCOME TO MY WORLD!"

x = str.casefold()

print(x)
# Out:
# hello all welcome to my world!

# %%
# Demo of center()
str = "Stars"

x = str.center(25, "*")

print(x)
# Out:
# **********Stars**********

# %%
# Demo of count()
str = "I love to eat grapes, grapes are my favorite fruit"

x = str.count("grapes")

print(x)
# Out:
# 2

# %%
#Demo of endswith()
str= "Hello, welcome to my castle."

end = str.endswith(("castle.", "story."))

print(end)
# Out:
# True

# %%
#Demo of SWAPCASE()
s='comPUTER IS an elecTRONIC deviCE'
print(s.swapcase())
# Out:
# COMputer is AN ELECtronic DEVIce

# %%
#Demo of title()
s='Python IS high LEVEL PROGRAMMING language'
print(s.title())
# Out:
# Python Is High Level Programming Language

# %%
#Demo of title()
s='Python IS high LEVEL PROGRAMMING language'
print(s.title())
# Out:
# Python Is High Level Programming Language

# %%
#Demo of strip()
s='**********Python is high level programming language***********'
print(s.strip('*'))
# Out:
# Python is high level programming language

# %%
#Demo of lstrip()
s='**********Python is high level programming language***********'
print(s.lstrip('*'))
# Out:
# Python is high level programming language***********

# %%
#Demo of rstrip()
s='**********Python is high level programming language***********'
print(s.rstrip('*'))
# Out:
# **********Python is high level programming language

# %%
# Demo of maketrans()
sen = "Hello Ealina"
replay = str.maketrans("E", "M")
print(sen.translate(replay))
# Out:
# Hello Malina

# %%
#Demo of replace(old,new)
s='Python is low level programming language'
print(s.replace('low','high'))
# Out:
# Python is high level programming language

# %%
#Demo of split()
s='Python is high level programming language'
print(s.split())
# Out:
# ['Python', 'is', 'high', 'level', 'programming', 'language']

# %%
#Demo of find()
s='Python is high level programming language'
print(s.find("l"))
# Out:
# 15

# %%
#Demo of expandtabs()
s='Python\tis\thigh\tlevel\tprogramming\tlanguage'
print(s.expandtabs(10))
# Out:
# Python    is        high      level     programming         language

# %%
#Demo of join()
s="&"
seq=("hello" , "how are you all")
print(s.join(seq))

D="-"
Date=(["31", "12", "2025"])
print(D.join(Date))
# Out:
# hello&how are you all
# 31-12-2025

# %%
#Demo of istitle()
s='Python IS high LEVEL PROGRAMMING language'
print(s.istitle())
s1='Python Is High Level Programming Language'
print(s1.istitle())
# Out:
# False
# True

# %%
#Demo of isalpha()
s="Python"
print(s.isalpha())
s1="Python12267788"
print(s1.isalpha())
# Out:
# True
# False

# %%
#Demo of isalnum()
s='*****Python'
print(s.isalnum())
s1='Python12267788'
print(s1.isalnum())
# Out:
# False
# True

# %%
#Demo of isdigit()
s='123456'
print(s.isdigit())
s1='122rtyy'
print(s1.isdigit())
# Out:
# True
# False

# %%
# Demo of partition()
str = "Hello everyone welcome to the world of AI"

x = str.partition("everyone")

print(x)
# Out:
# ('Hello ', 'everyone', ' welcome to the world of AI')

# %%
# Demo of splitlines()
str ="Hello everyone\n Welcome to the world of AI"

x = str.splitlines()

print(x)
# Out:
# ['Hello everyone', ' Welcome to the world of AI']

# %%
# Demo of Ljust()
str="Computer is an electronic device"
s = str.ljust(60 , "*")

print(s)
# Out:
# Computer is an electronic device****************************

# %%
# Demo of Rjust()
str="Computer is an electronic device"
s = str.rjust(60 , "*")

print(s)
# Out:
# ****************************Computer is an electronic device

# %%
# Demo of removeprefix()

str = "Hello everyone welcome to the world of AI"

x = str.removeprefix("Hello")

print(x)
# Out:
#  everyone welcome to the world of AI

# %%
# Demo of removesuffix()

str = "Hello everyone welcome to the world of AI"

x = str.removesuffix("of AI")

print(x)
# Out:
# Hello everyone welcome to the world

# %%
# Demo of index()
str = "Hello everyone welcome to the world of AI"

x = str.index("everyone")

print(x)
# Out:
# 6
